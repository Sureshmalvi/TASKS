# %%
import random
print("----------------------------------------")
print("--------LETS START GAME-----------------")
place=["Narendra modi stadium","Arun_jaitley_stadium","Green_park_stadium"]
print("::--TODAY MATCH IN ",random.choice(place),"Ground","--::")
Team=["CSK","RCB","MI","KKR","RR","KXIP"]
print(Team)
s=input("selected your team:").upper()
csk=["DHONI(W/B)","SURESH RAINA","BRAWO","CURRAN"]
rcb=["MAXWELL","AB DiVILLERS","VIRAT KOHLI","YUVENDRA CHAHAL"]
mi=["SURYAKUMAR YADAV","ROHIT SHARMA","HARDIK PANDAYA",]
kkr=["GAUTUM GHAMBHIR","ANDRE RUSSEL","NARAYAN","PIYUSH CHAWALA"]
rr=["WATSON","AJIKYA RAHENE","MILLER","HASRANGA"]
kxip=["GALLE","WARNER","FINCH","BUMRAH","PANT"]
score=[1,2,3,4,6,"wicket","no ball","wide_ball"]
if s in Team:
    print("you select:",s)
    if s=="CSK":
        x=random.choice(csk)
        print("first player:",x)
        while True:
            
            y=random.choice(csk)
            if x!=y:
                print("second player:",y)
                break
    elif s=="RCB":
        x=random.choice(rcb)
        print("first player:",x)
        while True:
            
            y=random.choice(rcb)
            if x!=y:
                print("second player:",y)
                break 
    elif s=="MI":
        x=random.choice(mi)
        print("first player:",x)
        while True:
            
            y=random.choice(mi)
            if x!=y:
                print("second player:",y)
                break

    elif s=="KKR":
        x=random.choice(kkr)
        print("first player:",x)
        while True:
            
            y=random.choice(kkr)
            if x!=y:
                print("second player:",y)
                break
    elif s=="RR":
        x=random.choice(rr)
        print("first player:",x)
        while True:
            
            y=random.choice(rr)
            if x!=y:
                print("second player:",y)
                break
       
    elif s=="KXIP":
        x=random.choice(kxip)
        print("first player:",x)
        while True:
            
            y=random.choice(kxip)
            if x!=y:
                print("second player:",y)
                break
c=random.choice(Team)
if c in Team:
    while True:
        if c!=s:
            print("OPPONENT TEAM IS:",c)
        break
print("---TOSS TIME---")
toss=["H","T"]
T=random.choice(toss)
print("""

press H for Head
press T for tell


""")
t=input("ENTER YOUR CHOICE:").upper()
if T==t:
    print("WINNER TEAM IS",s)
    print("""
     press 1 for BAT
     press 2 for BALL
    """)
    ch=int(input("WHAT YOU WANT TO DO :-"))
    if ch==1:
        print("WINNER TEAM CHOOSE BATING")
        ball=0
        run=0
        wicket=0
        while ball<6 and wicket<2:
            r=input()
            R=random.choice(score)
            if R==1:
                ball=ball+1
                run=run+1
                print(f"{s} ({run}/{wicket}) ({ball}) : {R}")
            elif R==2: 
                ball=ball+1
                run=run+2
                print(f"{s} ({run}/{wicket}) ({ball}) : {R}")
            elif R==3:
                ball=ball+1
                run=run+3
                print(f"{s} ({run}/{wicket}) ({ball}) : {R}")
            elif R==4:
                ball=ball+1
                run=run+4
                print(f"{s} ({run}/{wicket}) ({ball}) : {R}")
            elif R==6:
                ball=ball+1
                run=run+6
                print(f"{s} ({run}/{wicket}) ({ball}) : {R}")
            elif R=="wicket":
                ball=ball+1
                wicket=wicket+1
                print(f"{s} ({run}/{wicket}) ({ball}) : {R}")
            elif R=="wide_ball":
                ball=ball+0
                run=run+1
                print(f"{s} ({run}/{wicket}) ({ball}) : {R}")
            else:
                run=run+1
                ball=ball+0
                print(f"{s} ({run}/{wicket}) ({ball}) : {R}")
        r1=run
        print(F"{s} TEAM SCORE",r1,"RUN")
        print("OPPONENT TEAM BATING",c)
        ball=0
        run=0
        wicket=0
        while ball<6 and wicket<2:
            r=input()
            R=random.choice(score)
            if R==1:
                ball=ball+1
                run=run+1
                print(f"{c} ({run}/{wicket}) ({ball}) : {R}")
            elif R==2:
                ball=ball+1
                run=run+2
                print(f"{c} ({run}/{wicket}) ({ball}) : {R}")
            elif R==3:
                ball=ball+1
                run=run+3
                print(f"{c} ({run}/{wicket}) ({ball}) : {R}")
            elif R==4:
                ball=ball+1
                run=run+4
                print(f"{c} ({run}/{wicket}) ({ball}) : {R}")
            elif R==6:
                ball=ball+1
                run=run+6
                print(f"{c} ({run}/{wicket}) ({ball}) : {R}")
            elif R=="wicket":
                ball=ball+1
                wicket=wicket+1
                print(f"{c} ({run}/{wicket}) ({ball}) : {R}")
            elif R=="wide_ball":
                ball=ball+0
                run=run+1
                print(f"{c} ({run}/{wicket}) ({ball}) : {R}")
            else:
                run=run+1
                ball=ball+0
                print(f"{c} ({run}/{wicket}) ({ball}) : {R}")
        r2=run
        print(F"{c} TEAM SCORE",r2,"RUN")
        if r1>r2:
            print(f"WINNER TEAM IS :{s} FROM {r1-r2} RUN ")
        elif r1==r2:
            print("MATCH TIE")
        else:
            print(f"WINNER TEAM IS :{c} FROM {r2-r1} RUN ")
            
    else:
        print("winner team choose ball")
        ball=0
        run=0
        wicket=0
        while ball<6 and wicket<2:
            r=input()
            R=random.choice(score)
            if R==1:
                ball=ball+1
                run=run+1
                print(f"{c} ({run}/{wicket}) ({ball}) : {R}")
            elif R==2:
                ball=ball+1
                run=run+2
                print(f"{c} ({run}/{wicket}) ({ball}) : {R}")
            elif R==3:
                ball=ball+1
                run=run+3
                print(f"{c} ({run}/{wicket}) ({ball}) : {R}")
            elif R==4:
                ball=ball+1
                run=run+4
                print(f"{c} ({run}/{wicket}) ({ball}) : {R}")
            elif R==6:
                ball=ball+1
                run=run+6
                print(f"{c} ({run}/{wicket}) ({ball}) : {R}")
            elif R=="wicket":
                ball=ball+1
                wicket=wicket+1
                print(f"{c} ({run}/{wicket}) ({ball}) : {R}")
            elif R=="wide_ball":
                ball=ball+0
                run=run+1
                print(f"{c} ({run}/{wicket}) ({ball}) : {R}")
            else:
                run=run+1
                ball=ball+0
                print(f"{c} ({run}/{wicket}) ({ball}) : {R}")
        r1=run
        print(F"{c} TEAM SCORE",r1,"RUN")
        print("OPPONENT TEAM BATING",s)
        ball=0
        run=0
        wicket=0
        while ball<6 and wicket<2:
            r=input()
            R=random.choice(score)
            if R==1:
                ball=ball+1
                run=run+1
                print(f"{s} ({run}/{wicket}) ({ball}) : {R}")
            elif R==2: 
                ball=ball+1
                run=run+2
                print(f"{s} ({run}/{wicket}) ({ball}) : {R}")
            elif R==3:
                ball=ball+1
                run=run+3
                print(f"{s} ({run}/{wicket}) ({ball}) : {R}")
            elif R==4:
                ball=ball+1
                run=run+4
                print(f"{s} ({run}/{wicket}) ({ball}) : {R}")
            elif R==6:
                ball=ball+1
                run=run+6
                print(f"{s} ({run}/{wicket}) ({ball}) : {R}")
            elif R=="wicket":
                ball=ball+1
                wicket=wicket+1
                print(f"{s} ({run}/{wicket}) ({ball}) : {R}")
            elif R=="wide_ball":
                ball=ball+0
                run=run+1
                print(f"{s} ({run}/{wicket}) ({ball}) : {R}")
            else:
                run=run+1
                ball=ball+0
                print(f"{s} ({run}/{wicket}) ({ball}) : {R}")
        r2=run
        print(F"{s} TEAM SCORE",r2,"RUN")
        if r1>r2:
            print(f"WINNER TEAM IS :{c} FROM {r1-r2} RUN ")
        elif r1==r2:
            print("MATCH TIE")
        else:
            print(f"WINNER TEAM IS:{s} FROM {r2-r1} RUN ")

    
    
    
    
else:
    print("winner team is",c)
    print("""
     press 1 for BAT
     press 2 for BALL
    """)
    ch=int(input("WHAT YOU WANT TO DO"))
    if ch==1:
        print("WINNER TEAM BATING")
        ball=0
        run=0
        wicket=0
        while ball<6 and wicket<2:
            r=input()
            R=random.choice(score)
            if R==1:
                ball=ball+1
                run=run+1
                print(f"{c} ({run}/{wicket}) ({ball}) : {R}")
            elif R==2: 
                ball=ball+1
                run=run+2
                print(f"{c} ({run}/{wicket}) ({ball}) : {R}")
            elif R==3:
                ball=ball+1
                run=run+3
                print(f"{c} ({run}/{wicket}) ({ball}) : {R}")
            elif R==4:
                ball=ball+1
                run=run+4
                print(f"{c} ({run}/{wicket}) ({ball}) : {R}")
            elif R==6:
                ball=ball+1
                run=run+6
                print(f"{c} ({run}/{wicket}) ({ball}) : {R}")
            elif R=="wicket":
                ball=ball+1
                wicket=wicket+1
                print(f"{c} ({run}/{wicket}) ({ball}) : {R}")
            elif R=="wide_ball":
                ball=ball+0
                run=run+1
                print(f"{c} ({run}/{wicket}) ({ball}) : {R}")
            else:
                run=run+1
                ball=ball+0
                print(f"{c} ({run}/{wicket}) ({ball}) : {R}")
        r1=run
        print(F"{c} TEAM SCORE",r1,"RUN")
        print("OPPONENT TEAM BATING",s)
        ball=0
        run=0
        wicket=0
        while ball<6 and wicket<2:
            r=input()
            R=random.choice(score)
            if R==1:
                ball=ball+1
                run=run+1
                print(f"{s} ({run}/{wicket}) ({ball}) : {R}")
            elif R==2: 
                ball=ball+1
                run=run+2
                print(f"{s} ({run}/{wicket}) ({ball}) : {R}")
            elif R==3:
                ball=ball+1
                run=run+3
                print(f"{s} ({run}/{wicket}) ({ball}) : {R}")
            elif R==4:
                ball=ball+1
                run=run+4
                print(f"{s} ({run}/{wicket}) ({ball}) : {R}")
            elif R==6:
                ball=ball+1
                run=run+6
                print(f"{s} ({run}/{wicket}) ({ball}) : {R}")
            elif R=="wicket":
                ball=ball+1
                wicket=wicket+1
                print(f"{s} ({run}/{wicket}) ({ball}) : {R}")
            elif R=="wide_ball":
                ball=ball+0
                run=run+1
                print(f"{s} ({run}/{wicket}) ({ball}) : {R}")
            else:
                run=run+1
                ball=ball+0
                print(f"{s} ({run}/{wicket}) ({ball}) : {R}")
        r2=run
        print(F"{s} TEAM SCORE",r2,"RUN")
        if r1>r2:
            print(f"WINNER TEAM IS :{c} FROM {r1-r2} RUN")
        elif r1==r2:
            print("MATCH TIE")
        else:
            print(f"WINNER TEAM IS:{s} FROM {r2-r1} RUN")
    else:
        print("WINNER TEAM CHOOSE BALL")
        ball=0
        run=0
        wicket=0
        while ball<6 and wicket<2:
            r=input()
            R=random.choice(score)
            if R==1:
                ball=ball+1
                run=run+1
                print(f"{s} ({run}/{wicket}) ({ball}) : {R}")
            elif R==2:
                ball=ball+1
                run=run+2
                print(f"{s} ({run}/{wicket}) ({ball}) : {R}")
            elif R==3:
                ball=ball+1
                run=run+3
                print(f"{s} ({run}/{wicket}) ({ball}) : {R}")
            elif R==4:
                ball=ball+1
                run=run+4
                print(f"{s} ({run}/{wicket}) ({ball}) : {R}")
            elif R==6:
                ball=ball+1
                run=run+6
                print(f"{s} ({run}/{wicket}) ({ball}) : {R}")
            elif R=="wicket":
                ball=ball+1
                wicket=wicket+1
                print(f"{s} ({run}/{wicket}) ({ball}) : {R}")
            elif R=="wide_ball":
                ball=ball+0
                run=run+1
                print(f"{s} ({run}/{wicket}) ({ball}) : {R}")
            else:
                run=run+1
                ball=ball+0
                print(f"{s} ({run}/{wicket}) ({ball}) : {R}")
        r1=run
        print(F"{s} TEAM SCORE",r1,"RUN")
        print("OPPONENT TEAM BATING",c)
        ball=0
        run=0
        wicket=0
        while ball<6 and wicket<2:
            r=input()
            R=random.choice(score)
            if R==1:
                ball=ball+1
                run=run+1
                print(f"{c} ({run}/{wicket}) ({ball}) : {R}")
            elif R==2: 
                ball=ball+1
                run=run+2
                print(f"{c} ({run}/{wicket}) ({ball}) : {R}")
            elif R==3:
                ball=ball+1
                run=run+3
                print(f"{c} ({run}/{wicket}) ({ball}) : {R}")
            elif R==4:
                ball=ball+1
                run=run+4
                print(f"{c} ({run}/{wicket}) ({ball}) : {R}")
            elif R==6:
                ball=ball+1
                run=run+6
                print(f"{c} ({run}/{wicket}) ({ball}) : {R}")
            elif R=="wicket":
                ball=ball+1
                wicket=wicket+1
                print(f"{c} ({run}/{wicket}) ({ball}) : {R}")
            elif R=="wide_ball":
                ball=ball+0
                run=run+1
                print(f"{c} ({run}/{wicket}) ({ball}) : {R}")
            else:
                run=run+1
                ball=ball+0
                print(f"{c} ({run}/{wicket}) ({ball}) : {R}")
        r2=run
        print(F"{s} TEAM SCORE",r1,"RUN")
        if r1>r2:
            print(f"WINNER TEAM IS :{s} FROM {r1-r2} RUN")
        elif r1==r2:
            print("MATCH TIE")
        else:
            print(f"WINNER TEAM IS:{c} FROM {r2-r1} RUN")
# Out:
# ----------------------------------------
# --------LETS START GAME-----------------
# ::--TODAY MATCH IN  Narendra modi stadium Ground --::
# ['CSK', 'RCB', 'MI', 'KKR', 'RR', 'KXIP']
# selected your team:csk
# you select: CSK
# first player: DHONI(W/B)
# second player: SURESH RAINA
# OPPONENT TEAM IS: KKR
# ---TOSS TIME---
#
#
# press H for Head
# press T for tell
#
#
#
# ENTER YOUR CHOICE:h
# WINNER TEAM IS CSK
#
#      press 1 for BAT
#      press 2 for BALL
#
# WHAT YOU WANT TO DO :-1
# WINNER TEAM CHOOSE BATING
#
# CSK (6/0) (1) : 6
#
# CSK (9/0) (2) : 3
#
# CSK (12/0) (3) : 3
#
# CSK (14/0) (4) : 2
#
# CSK (20/0) (5) : 6
#
# CSK (24/0) (6) : 4
# CSK TEAM SCORE 24 RUN
# OPPONENT TEAM BATING KKR
#
# KKR (1/0) (1) : 1
#
# KKR (3/0) (2) : 2
#
# KKR (7/0) (3) : 4
#
# KKR (7/1) (4) : wicket
#
# KKR (11/1) (5) : 4
#
# KKR (11/2) (6) : wicket
# KKR TEAM SCORE 11 RUN
# WINNER TEAM IS :CSK FROM 13 RUN

# %%
#
