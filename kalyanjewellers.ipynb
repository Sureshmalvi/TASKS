# %%
print("kalyan jewellers")

x=input("Enter your name:")
y=int(input("Enter your mobile number:"))
g=input("Enter your gender:")
if g=="m" or g=="f":
    pass
else:
    print("invalid input")
z=int(input("Enter your age:"))
p=input("Enter your product name:")
Q=int(input("Enter your quantity in gm:"))
print("current price of 1 gm=5000")
print("making charges of 10 gm of gold is 600. -/- ")
print("-----------------------------------------------")
if g=="m" and z<65:
    W=Q*5000
    G=((Q*5000)*3)/100
    to=W+G
    print("GST(3%):-",G)
    print("your Amount is:",to)
    print("thank you for shoping with us")
    print("---------------------------------------------")
    if W<200000:
        if Q<10:
            print("No Making Charge")
        elif Q>10 or Q<20:
            print("your making charge is:",Q*50,'-/-')
            print("GST:",((W*3)/100),"-/-")
            P=W+((W*3)/100)+Q*50
            print("you have to pay:",P, "-/-")
    elif W>200000 and W<500000:
        f=(W-((W*5)/100))
        print("your discount is",((W*5)/100),'-/-' )
        m=Q*60
        print("your making charge is:",m,'-/-')
        print("GST:",((f*3)/100))
        t=f+((f*3)/100)
        print("you have to pay:",t, "-/-")
    elif W>500000 and W<1000000:
        f=(W-((W*10)/100))
        print("your discount is",((W*10)/100),'-/-' )
        m=Q*60
        print("your making charge is:",m,'-/-')
        print("GST:",((f*3)/100))
        t=f+((f*3)/100)
        print("you have to pay:",t, "-/-")
    elif W>1000000:
        f=(W-((W*15)/100))
        print("your discount is",((W*15)/100),'-/-' )
        m=Q*60
        print("your making charge is:",m,'-/-')
        print("GST:",((f*3)/100))
        t=f+((f*3)/100)
        print("you have to pay:",t, "-/-")    
if g=="m" and z>65:
    W=Q*5000
    print("your amount is:",W)
    if W<200000:
        m=Q*60
        print("your making charge is:",m,'-/-')
        print("GST:",((f*3)/100))
        P=W+((f*3)/100)+m
        print("you have to pay:",P, "-/-")
    elif W>200000 and W<500000:
        f=(W-((W*10)/100))
        print("your discount is",((W*10)/100),'-/-' )
        m=Q*60
        print("your making charge is:",m,'-/-')
        print("GST:",((f*3)/100))
        t=f+((f*3)/100)
        print("you have to pay:",t, "-/-")
    elif W>500000 and W<1000000:
        f=(W-((W*15)/100))
        print("your discount is",((W*15)/100),'-/-' )
        m=Q*60
        print("your making charge is:",m,'-/-')
        print("GST:",((f*3)/100))
        t=f+((f*3)/100)
        print("you have to pay:",t, "-/-")
    elif W>1000000:
        f=(W-((W*20)/100))
        print("your discount is",((W*20)/100),'-/-' )
        m=Q*60
        print("your making charge is:",m,'-/-')
        print("GST:",((f*3)/100))
        t=f+((f*3)/100)
        print("you have to pay:",t, "-/-")
if g=="f" and z<65:
    W=Q*5000
    print("your amount is:",W)
    if W<200000:
        m=Q*60
        print("your making charge is:",m,'-/-')
        print("GST:",((f*3)/100))
        P=W+((f*3)/100)+m
        print("you have to pay:",P, "-/-")
    elif W>200000 and W<500000:
        f=(W-((W*10)/100))
        print("your discount is",((W*15)/100),'-/-' )
        m=Q*60
        print("your making charge is:",m,'-/-')
        print("GST:",((f*3)/100))
        t=f+((f*3)/100)
        print("you have to pay:",t, "-/-")
    elif W>500000 and W<1000000:
        f=(W-((W*15)/100))
        print("your discount is",((W*15)/100),'-/-' )
        m=Q*60
        print("your making charge is:",m,'-/-')
        print("GST:",((f*3)/100))
        t=f+((f*3)/100)
        print("you have to pay:",t, "-/-")
    elif W>1000000:
        f=(W-((W*20)/100))
        print("your discount is",((W*20)/100),'-/-' )
        m=Q*60
        print("your making charge is:",m,'-/-')
        print("GST:",((f*3)/100))
        t=f+((f*3)/100)
        print("you have to pay:",t, "-/-")
if g=="f" and z>65:
    W=Q*5000
    print("your amount is:",W)
    if W<200000:
        m=Q*60
        print("your making charge is:",m,'-/-')
        print("GST:",((f*3)/100))
        P=W+((f*3)/100)+m
        print("you have to pay:",P, "-/-")
    elif W>200000 and W<500000:
        f=(W-((W*15)/100))
        print("your discount is",((W*15)/100),'-/-' )
        m=Q*60
        print("your making charge is:",m,'-/-')
        print("GST:",((f*3)/100))
        t=f+((f*3)/100)
        print("you have to pay:",t, "-/-")
    elif W>500000 and W<1000000:
        f=(W-((W*20)/100))
        print("your discount is",((W*20)/100),'-/-' )
        m=Q*60
        print("your making charge is:",m,'-/-')
        print("GST:",((f*3)/100))
        t=f+((f*3)/100)
        print("you have to pay:",t, "-/-")
    elif W>1000000:
        f=(W-((W*25)/100))
        print("your discount is",((W*25)/100),'-/-' )
        m=Q*60
        print("your making charge is:",m,'-/-')
        print("GST:",((f*3)/100))
        t=f+((f*3)/100)
        print("you have to pay:",t, "-/-")
# Out:
# kalyan jewellers
# Enter your name:ss
# Enter your mobile number:23
# Enter your gender:m
# Enter your age:88
# Enter your product name:sd
# Enter your quantity in gm:155
# current price of 1 gm=5000
# making charges of 10 gm of gold is 600. -/-
# -----------------------------------------------
# your amount is: 775000
# your discount is 116250.0 -/-
# your making charge is: 9300 -/-
# GST: 19762.5
# you have to pay: 678512.5 -/-

# %%
def menu():
    data="""
    press 1 for addition
    press 2 for multipication
    
    
    """
    print(data)
    choice=int(input("enter your choice"))
    num1=int(input("enter number 1:"))
    num2=int(input("enter number 2:"))
    if choice==1:
        print(addition(num1,num2))
    elif choice==2:
        print(multipication(num1,num2))
    else:
        print("invalid input")
def addition(n1,n2):
    ans=n1+n2
    return ans
def multipication(n1,n2):
    ans=n1+n2
    return ans
